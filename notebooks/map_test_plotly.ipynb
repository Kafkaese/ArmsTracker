# %%
import geopandas
import plotly.express as px
import streamlit

# %%
world = geopandas.read_file('../data/geo/world.geojson')

# %%
world.drop(columns = ['zoneName', 'countryKey'], inplace = True)

# %%
world.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
fig = px.choropleth(world, geojson=world,
                    scope='world',
                           labels={'Name':'country'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="0ae0d95c-1271-4505-976a-e260080e4076" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ae0d95c-1271-4505-976a-e260080e4076")) {                    Plotly.newPlot(                        "0ae0d95c-1271-4505-976a-e260080e4076",                        [],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","mi
# ...

# %%
import streamlit as st

import geopandas
import plotly.express as px


world = geopandas.read_file('../data/geo/world.geojson')

world.drop(columns = ['zoneName', 'countryKey'], inplace = True)

st.pyplot(world.explore())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 11>()
#       7 world = geopandas.read_file('../data/geo/world.geojson')
#       9 world.drop(columns = ['zoneName', 'countryKey'], inplace = True)
# ---> 11 st.pyplot(world.explore())
#
# File ~/.pyenv/versions/taro/lib/python3.8/site-packages/streamlit/elements/pyplot.py:92, in PyplotMixin.pyplot(self, fig, clear_figure, **kwargs)
#      89     self.dg.exception(PyplotGlobalUseWarning())
#      91 image_list_proto = ImageListProto()
# ---> 92 marshall(
#      93     self.dg._get_delta_path_str(), image_list_proto, fig, clear_figure, **kwargs
#      94 )
#      95 return self.dg._enqueue("imgs", image_list_proto)
#
# File ~/.pyenv/versions/taro/lib/python3.8/site-packages/streamlit/elements/pyplot.py:132, in marshall(coordinates, image_list_proto, fig, clear_figure, **kwargs)
# ...
